# %% [markdown]
# Connected to Python 3.10.12

# %%
world_map = alt.topo_feature(data.world_110m.url, 'countries')

# Ensure Year is numeric
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Aggregate by year and country
yearly_counts = df.groupby(['Year', 'Country']).agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

# Create a year slider parameter
year_slider = alt.binding_range(min=yearly_counts['Year'].min(), max=yearly_counts['Year'].max(), step=1)
year_select = alt.param(
    name='Year',
    bind=year_slider,
    value=int(yearly_counts['Year'].min())
)

# World map base (assuming you have world_map loaded already)
base = alt.Chart(world_map).mark_geoshape(
    fill='lightgray', stroke='white'
).project('equalEarth').properties(width=00, height=500)

year_param = alt.param(
    name="YearSelector",
    bind=alt.binding_range(min=int(df['Year'].min()), max=int(df['Year'].max()), step=1, name="Year"),
    value=int(df['Year'].min())
)

# Bubble chart filtered by selected year
year_bubbles = alt.Chart(yearly_counts).mark_circle(opacity=0.7, color='crimson').encode(
    longitude='Longitude:Q',
    latitude='Latitude:Q',
    size=alt.Size('Incident Count:Q', scale=alt.Scale(range=[10, 1000]), legend=alt.Legend(title="Incident Count")),
    tooltip=['Country:N', 'Incident Count:Q', 'Year:O']
).transform_filter(
    alt.datum.Year == year_select
)

# Combine map + param
chart = (base + year_bubbles).add_params(year_param).properties(title="Global Security Incidents Over Time")
chart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/mini_project/python.qmd in <module>
# ----> 1 world_map = alt.topo_feature(data.world_110m.url, 'countries')
#       2
#       3 # Ensure Year is numeric
#       4 df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
#       5
#
# NameError: name 'alt' is not defined

# %%
import altair as alt
from vega_datasets import data
import pandas as pd

import pandas as pd

df = pd.read_csv('./security_incidents.csv')

# %%
world_map = alt.topo_feature(data.world_110m.url, 'countries')

# Ensure Year is numeric
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Aggregate by year and country
yearly_counts = df.groupby(['Year', 'Country']).agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

# Create a year slider parameter
year_slider = alt.binding_range(min=yearly_counts['Year'].min(), max=yearly_counts['Year'].max(), step=1)
year_select = alt.param(
    name='Year',
    bind=year_slider,
    value=int(yearly_counts['Year'].min())
)

# World map base (assuming you have world_map loaded already)
base = alt.Chart(world_map).mark_geoshape(
    fill='lightgray', stroke='white'
).project('equalEarth').properties(width=00, height=500)

year_param = alt.param(
    name="YearSelector",
    bind=alt.binding_range(min=int(df['Year'].min()), max=int(df['Year'].max()), step=1, name="Year"),
    value=int(df['Year'].min())
)

# Bubble chart filtered by selected year
year_bubbles = alt.Chart(yearly_counts).mark_circle(opacity=0.7, color='crimson').encode(
    longitude='Longitude:Q',
    latitude='Latitude:Q',
    size=alt.Size('Incident Count:Q', scale=alt.Scale(range=[10, 1000]), legend=alt.Legend(title="Incident Count")),
    tooltip=['Country:N', 'Incident Count:Q', 'Year:O']
).transform_filter(
    alt.datum.Year == year_select
)

# Combine map + param
chart = (base + year_bubbles).add_params(year_param).properties(title="Global Security Incidents Over Time")
chart
# Out:
# alt.LayerChart(...)

# %%
world_map = alt.topo_feature(data.world_110m.url, 'countries')

# Ensure Year is numeric
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Aggregate by year and country
yearly_counts = df.groupby(['Year', 'Country']).agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

# Create a year slider parameter
year_slider = alt.binding_range(min=yearly_counts['Year'].min(), max=yearly_counts['Year'].max(), step=1)
year_select = alt.param(
    name='Year',
    bind=year_slider,
    value=int(yearly_counts['Year'].min())
)

# World map base (assuming you have world_map loaded already)
base = alt.Chart(world_map).mark_geoshape(
    fill='lightgray', stroke='white'
).project('equalEarth').properties(width=00, height=500)

year_param = alt.param(
    name="YearSelector",
    bind=alt.binding_range(min=int(df['Year'].min()), max=int(df['Year'].max()), step=1, name="Year"),
    value=int(df['Year'].min())
)

# Bubble chart filtered by selected year
year_bubbles = alt.Chart(yearly_counts).mark_circle(opacity=0.7, color='crimson').encode(
    longitude='Longitude:Q',
    latitude='Latitude:Q',
    size=alt.Size('Incident Count:Q', scale=alt.Scale(range=[10, 1000]), legend=alt.Legend(title="Incident Count")),
    tooltip=['Country:N', 'Incident Count:Q', 'Year:O']
).transform_filter(
    alt.datum.Year == year_select
)

# Combine map + param
chart = (base + year_bubbles).add_params(year_param).properties(title="Global Security Incidents Over Time")
chart
# Out:
# alt.LayerChart(...)

# %%
# 1. Load world map shape
world_map = alt.topo_feature(data.world_110m.url, 'countries')

# 2. Make sure Year is numeric
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# 3. Aggregate
yearly_counts = df.groupby(['Year', 'Country']).agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

# 4. Slider for Year
year_slider = alt.binding_range(min=yearly_counts['Year'].min(), max=yearly_counts['Year'].max(), step=1)
year_select = alt.param(name='Year', bind=year_slider, value=int(yearly_counts['Year'].min()))

# 5. Base world map
base = alt.Chart(world_map).mark_geoshape(
    fill='lightgray', stroke='white'
).project('equalEarth').properties(width=900, height=500)

# 6. Bubbles
year_bubbles = alt.Chart(yearly_counts).mark_circle(opacity=0.7, color='crimson').encode(
    longitude='Longitude:Q',
    latitude='Latitude:Q',
    size=alt.Size('Incident Count:Q', scale=alt.Scale(range=[10, 1000]), legend=alt.Legend(title="Incident Count")),
    tooltip=['Country:N', 'Incident Count:Q', 'Year:O']
).transform_filter(
    alt.datum.Year == year_select
)

# 7. Combine
chart = (base + year_bubbles).add_params(year_select)
chart
# Out:
# alt.LayerChart(...)

# %%
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# Group by Year and Month
monthly_counts = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# Build the heatmap
heatmap = alt.Chart(monthly_counts).mark_rect().encode(
    x=alt.X('Month:O', title='Month', sort=list(range(1, 13))),
    y=alt.Y('Year:O', title='Year', sort='descending'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incident Count'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(
    width=500,
    height=400,
    title='Calendar Heatmap of Incidents by Year and Month'
)

heatmap
# Out:
# alt.Chart(...)

# %%
# Create bar chart with text labels
bars = alt.Chart(monthly_counts).mark_bar().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Incident Count:Q', title='Incidents'),
    color=alt.Color('Month:O', legend=None)
).properties(
    width=600,
    height=300,
    title="Monthly Incident Counts Over the Years"
)

# Add count labels
text = bars.mark_text(
    align='center',
    baseline='bottom',
    dy=-2  # move text slightly above bars
).encode(
    text='Incident Count:Q'
)

# Optional: add month facets
chart = (bars + text).facet(
    row=alt.Row('Month:O', title='Month', sort=list(range(1, 13)))
)

chart
# Out:
# alt.FacetChart(...)

# %%
# Ensure correct types
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data: incidents by (Year, Month)
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Bar Chart Data: total incidents by Month
monthly_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# --- Heatmap
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Month:O', title='Month', sort=list(range(1, 13))),
    y=alt.Y('Year:O', title='Year', sort='descending'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incident Count'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(
    width=500,
    height=400,
    title='Monthly Incident Heatmap (Year × Month)'
)

# --- Side Bar Chart (Total per Month)
bar = alt.Chart(monthly_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=list(range(1, 13)), title=None),
    x=alt.X('Total Incidents:Q', title='Total Incidents'),
    tooltip=['Month:O', 'Total Incidents:Q']
).properties(
    width=150,
    height=400,
    title='Total Incidents by Month'
)

# --- Combine: Side-by-side layout
chart = alt.hconcat(
    bar,
    heatmap
).resolve_scale(
    y='shared'  # ensures both charts align by Month
)

chart
# Out:
# alt.HConcatChart(...)

# %%
import pandas as pd
import altair as alt

# Prepare data
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data: Year × Month
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Bar Chart Data: per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Bar Chart Data: per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=list(range(1, 13)), title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Top bar chart: Incidents by Year
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=list(range(1, 13)), title=None),
    x=alt.X('Total Incidents:Q', title='Incidents')
).properties(width=100, height=300)

# --- Combine center (left bar + heatmap)
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

# --- Full layout: top + middle
final_chart = alt.vconcat(
    top_bar,
    middle
).resolve_scale(
    x='shared'
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_bar,
    middle
).resolve_scale(
    x='shared'
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_point(opacity=0).encode(
    x=alt.X('x:Q', axis=None)
).properties(
    width=100,
    height=100,
    background=None  # No plot background
).configure_view(
    stroke=None  # No chart border
)

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

# --- Adjusted top row: spacer + top bar
top_row = alt.hconcat(
    spacer,
    top_bar
)

# --- Final layout: adjusted top + middle
final_chart = alt.vconcat(
    top_row,
    middle
).resolve_scale(
    x='shared'
)

final_chart
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# ~/mini_project/python.qmd in <module>
#      27
#      28 # --- Transparent spacer (dummy chart to offset left)
# ---> 29 spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_point(opacity=0).encode(
#      30     x=alt.X('x:Q', axis=None)
#      31 ).properties(
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in properties(self, **kwargs)
#    2396                 # Don't validate data, because it hasn't been processed.
#    2397                 if key != "data":
# -> 2398                     _top_schema_base(self).validate_property(key, val)
#    2399                 setattr(copy, key, val)
#    2400         return t.cast("Self", copy)
#
# ~/.local/lib/python3.10/site-packages/altair/utils/schemapi.py in validate_property(cls, name, value, schema)
#    1303         value = _todict(value, context={}, **opts)
#    1304         props = cls.resolve_references(schema or cls._schema).get("properties", {})
# -> 1305         validate_jsonschema(
#    1306             value, props.get(name, {}), rootschema=cls._rootschema or cls._schema
#    1307         )
#
# ~/.local/lib/python3.10/site-packages/altair/utils/schemapi.py in validate_jsonschema(spec, schema, rootschema, raise_error)
#     164         main_error._all_errors = grouped_errors
#     165         if raise_error:
# --> 166             raise main_error
#     167         else:
#     168             return main_error
#
# ValidationError: None is not one of ['black', 'silver', 'gray', 'white', 'maroon', 'red', 'purple', 'fuchsia', 'green', 'lime', 'olive', 'yellow', 'navy', 'blue', 'teal', 'aqua', 'orange', 'aliceblue', 'antiquewhite', 'aquamarine', 'azure', 'beige', 'bisque', 'blanchedalmond', 'blueviolet', 'brown', 'burlywood', 'cadetblue', 'chartreuse', 'chocolate', 'coral', 'cornflowerblue', 'cornsilk', 'crimson', 'cyan', 'darkblue', 'darkcyan', 'darkgoldenrod', 'darkgray', 'darkgreen', 'darkgrey', 'darkkhaki', 'darkmagenta', 'darkolivegreen', 'darkorange', 'darkorchid', 'darkred', 'darksalmon', 'darkseagreen', 'darkslateblue', 'darkslategray', 'darkslategrey', 'darkturquoise', 'darkviolet', 'deeppink', 'deepskyblue', 'dimgray', 'dimgrey', 'dodgerblue', 'firebrick', 'floralwhite', 'forestgreen', 'gainsboro', 'ghostwhite', 'gold', 'goldenrod', 'greenyellow', 'grey', 'honeydew', 'hotpink', 'indianred', 'indigo', 'ivory', 'khaki', 'lavender', 'lavenderblush', 'lawngreen', 'lemonchiffon', 'lightblue', 'lightcoral', 'lightcyan', 'lightgoldenrodyellow', 'lightgray', 'lightgreen', 'lightgrey', 'lightpink', 'lightsalmon', 'lightseagreen', 'lightskyblue', 'lightslategray', 'lightslategrey', 'lightsteelblue', 'lightyellow', 'limegreen', 'linen', 'magenta', 'mediumaquamarine', 'mediumblue', 'mediumorchid', 'mediumpurple', 'mediumseagreen', 'mediumslateblue', 'mediumspringgreen', 'mediumturquoise', 'mediumvioletred', 'midnightblue', 'mintcream', 'mistyrose', 'moccasin', 'navajowhite', 'oldlace', 'olivedrab', 'orangered', 'orchid', 'palegoldenrod', 'palegreen', 'paleturquoise', 'palevioletred', 'papayawhip', 'peachpuff', 'peru', 'pink', 'plum', 'powderblue', 'rosybrown', 'royalblue', 'saddlebrown', 'salmon', 'sandybrown', 'seagreen', 'seashell', 'sienna', 'skyblue', 'slateblue', 'slategray', 'slategrey', 'snow', 'springgreen', 'steelblue', 'tan', 'thistle', 'tomato', 'turquoise', 'violet', 'wheat', 'whitesmoke', 'yellowgreen', 'rebeccapurple']
#
# Failed validating 'enum' in schema[0]:
#     {'enum': ['black',
#               'silver',
#               'gray',
#               'white',
#               'maroon',
#               'red',
#               'purple',
#               'fuchsia',
#               'green',
#               'lime',
#               'olive',
#               'yellow',
#               'navy',
#               'blue',
#               'teal',
#               'aqua',
#               'orange',
#               'aliceblue',
#               'antiquewhite',
#               'aquamarine',
#               'azure',
#               'beige',
#               'bisque',
#               'blanchedalmond',
#               'blueviolet',
#               'brown',
#               'burlywood',
#               'cadetblue',
#               'chartreuse',
#               'chocolate',
#               'coral',
#               'cornflowerblue',
#               'cornsilk',
#               'crimson',
#               'cyan',
#               'darkblue',
#               'darkcyan',
#               'darkgoldenrod',
#               'darkgray',
#               'darkgreen',
#               'darkgrey',
#               'darkkhaki',
#               'darkmagenta',
#               'darkolivegreen',
#               'darkorange',
#               'darkorchid',
#               'darkred',
#               'darksalmon',
#               'darkseagreen',
#               'darkslateblue',
#               'darkslategray',
#               'darkslategrey',
#               'darkturquoise',
#               'darkviolet',
#               'deeppink',
#               'deepskyblue',
#               'dimgray',
#               'dimgrey',
#               'dodgerblue',
#               'firebrick',
#               'floralwhite',
#               'forestgreen',
#               'gainsboro',
#               'ghostwhite',
#               'gold',
#               'goldenrod',
#               'greenyellow',
#               'grey',
#               'honeydew',
#               'hotpink',
#               'indianred',
#               'indigo',
#               'ivory',
#               'khaki',
#               'lavender',
#               'lavenderblush',
#               'lawngreen',
#               'lemonchiffon',
#               'lightblue',
#               'lightcoral',
#               'lightcyan',
#               'lightgoldenrodyellow',
#               'lightgray',
#               'lightgreen',
#               'lightgrey',
#               'lightpink',
#               'lightsalmon',
#               'lightseagreen',
#               'lightskyblue',
#               'lightslategray',
#               'lightslategrey',
#               'lightsteelblue',
#               'lightyellow',
#               'limegreen',
#               'linen',
#               'magenta',
#               'mediumaquamarine',
#               'mediumblue',
#               'mediumorchid',
#               'mediumpurple',
#               'mediumseagreen',
#               'mediumslateblue',
#               'mediumspringgreen',
#               'mediumturquoise',
#               'mediumvioletred',
#               'midnightblue',
#               'mintcream',
#               'mistyrose',
#               'moccasin',
#               'navajowhite',
#               'oldlace',
#               'olivedrab',
#               'orangered',
#               'orchid',
#               'palegoldenrod',
#               'palegreen',
#               'paleturquoise',
#               'palevioletred',
#               'papayawhip',
#               'peachpuff',
#               'peru',
#               'pink',
#               'plum',
#               'powderblue',
#               'rosybrown',
#               'royalblue',
#               'saddlebrown',
#               'salmon',
#               'sandybrown',
#               'seagreen',
#               'seashell',
#               'sienna',
#               'skyblue',
#               'slateblue',
#               'slategray',
#               'slategrey',
#               'snow',
#               'springgreen',
#               'steelblue',
#               'tan',
#               'thistle',
#               'tomato',
#               'turquoise',
#               'violet',
#               'wheat',
#               'whitesmoke',
#               'yellowgreen',
#               'rebeccapurple'],
#      'type': 'string'}
#
# On instance:
#     None

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_bar(opacity=0).encode(
    x=alt.X('x:Q')
).properties(width=100, height=100)  # width must match left_bar

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_bar,
    middle
).resolve_scale(
    x='shared'
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_bar(opacity=0).encode(
    x=alt.X('x:Q')
).properties(width=100, height=100)  # width must match left_bar

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_row,
    middle
).resolve_scale(
    x='shared'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/mini_project/python.qmd in <module>
#      53 # --- Final layout: top + (left + heatmap)
#      54 final_chart = alt.vconcat(
# ---> 55     top_row,
#      56     middle
#      57 ).resolve_scale(
#
# NameError: name 'top_row' is not defined

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_bar(opacity=0).encode(
    x=alt.X('x:Q')
).properties(width=100, height=100)  # width must match left_bar

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

top_row = alt.hconcat(
    spacer,
    top_bar
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_row,
    middle
).resolve_scale(
    x='shared'
)

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_bar(opacity=0).encode(
    x=alt.X('x:Q')
).properties(width=100, height=100)  # width must match left_bar

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

top_row = alt.hconcat(
    spacer,
    top_bar
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_row,
    middle
).resolve_scale(
    x='shared'
)

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_bar(opacity=0).encode(
    x=alt.X('x:Q')
).properties(width=100, height=100)  # width must match left_bar

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

top_row = alt.hconcat(
    spacer,
    top_bar
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_row,
    middle
).resolve_scale(
    x='shared'
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_bar(opacity=0).encode(
    x=alt.X('x:Q')
).properties(width=100, height=100, backgraound=None).configure_view(
    stroke=None
)  # width must match left_bar

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

top_row = alt.hconcat(
    spacer,
    top_bar
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_row,
    middle
).resolve_scale(
    x='shared'
)

final_chart
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/mini_project/python.qmd in <module>
#      53 )
#      54
# ---> 55 top_row = alt.hconcat(
#      56     spacer,
#      57     top_bar
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in hconcat(*charts, **kwargs)
#    4522 def hconcat(*charts: ConcatType, **kwargs: Any) -> HConcatChart:
#    4523     """Concatenate charts horizontally."""
# -> 4524     return HConcatChart(hconcat=charts, **kwargs)
#    4525
#    4526
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in __init__(self, data, hconcat, **kwargs)
#    4432     ) -> None:
#    4433         for spec in hconcat:
# -> 4434             _check_if_valid_subspec(spec, "HConcatChart")
#    4435         super().__init__(data=data, hconcat=list(hconcat), **kwargs)  # type: ignore[arg-type]
#    4436         self.hconcat: list[ChartType]
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in _check_if_valid_subspec(spec, classname)
#    4126                 f"Consider defining the {attr} attribute in the {classname} object instead."
#    4127             )
# -> 4128             raise TypeError(msg)
#    4129
#    4130
#
# TypeError: Objects with 'config' attribute cannot be used within HConcatChart. Consider defining the config attribute in the HConcatChart object instead.

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_bar(opacity=0).encode(
    x=alt.X('x:Q')
).properties(width=100, height=100, backgraound=None)
)  # width must match left_bar

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

top_row = alt.hconcat(
    spacer,
    top_bar
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_row,
    middle
).resolve_scale(
    x='shared'
)

final_chart
# Out:
#   File "<ipython-input-18-7d052704c6e4>", line 32
#     )  # width must match left_bar
#     ^
# SyntaxError: unmatched ')'

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_bar(opacity=0).encode(
    x=alt.X('x:Q')
).properties(width=100, height=100, backgraound=None)
  # width must match left_bar

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

top_row = alt.hconcat(
    spacer,
    top_bar
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_row,
    middle
).resolve_scale(
    x='shared'
)

final_chart
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in to_dict(self, validate, format, ignore, context)
#    2002         context["top_level"] = False
#    2003
# -> 2004         vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005             validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006         )
#
# ~/.local/lib/python3.10/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#    1167                 self.validate(result)
#    1168             except jsonschema.ValidationError as err:
# -> 1169                 raise SchemaValidationError(self, err) from None
#    1170         return result
#    1171
#
# SchemaValidationError: `VConcatChart` has no parameter named 'backgraound'
#
# Existing parameter names are:
# vconcat      center     description   params    title
# autosize     config     name          resolve   transform
# background   data       padding       spacing   usermeta
# bounds       datasets
#
# See the help for `VConcatChart` to read the full description of these parameters
# alt.VConcatChart(...)

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_bar(opacity=0).encode(
    x=alt.X('x:Q')
).properties(width=100, height=100)
  # width must match left_bar

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

top_row = alt.hconcat(
    spacer,
    top_bar
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_row,
    middle
).resolve_scale(
    x='shared'
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_point(opacity=0).encode(
    x=alt.X('x:Q')
).properties(width=100, height=100)
  # width must match left_bar

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

top_row = alt.hconcat(
    spacer,
    top_bar
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_row,
    middle
).resolve_scale(
    x='shared'
).configure_view(
    stroke=None  # Remove borders from all charts
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
import pandas as pd
import altair as alt

# Convert types just in case
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')

# --- Heatmap Data
heatmap_data = df.groupby(['Year', 'Month']).size().reset_index(name='Incident Count')

# --- Totals per Year
year_totals = df.groupby('Year').size().reset_index(name='Total Incidents')

# --- Totals per Month
month_totals = df.groupby('Month').size().reset_index(name='Total Incidents')

# Sort months as 1 to 12 for consistency
month_order = list(range(1, 13))

# --- Heatmap: center
heatmap = alt.Chart(heatmap_data).mark_rect().encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Month:O', sort=month_order, title='Month'),
    color=alt.Color('Incident Count:Q', scale=alt.Scale(scheme='reds'), title='Incidents'),
    tooltip=['Year:O', 'Month:O', 'Incident Count:Q']
).properties(width=500, height=300)

# --- Transparent spacer (dummy chart to offset left)
spacer = alt.Chart(pd.DataFrame({'x': [0]})).mark_point(opacity=0).encode(
    x=alt.X('x:Q', axis=None)
).properties(width=100, height=100)
  # width must match left_bar

# --- Top bar chart: Incidents by Year (aligned with heatmap x-axis)
top_bar = alt.Chart(year_totals).mark_bar(color='steelblue').encode(
    x=alt.X('Year:O', title=None),  # Must match heatmap x
    y=alt.Y('Total Incidents:Q', title='Incidents')
).properties(width=500, height=100)

# --- Left bar chart: Incidents by Month (flipped to match heatmap y-axis)
left_bar = alt.Chart(month_totals).mark_bar(color='steelblue').encode(
    y=alt.Y('Month:O', sort=month_order, title=None),  # Must match heatmap y
    x=alt.X('Total Incidents:Q', title='Incidents', scale=alt.Scale(reverse=True))  # Reverse for 180 flip
).properties(width=100, height=300)

# --- Middle row: left + heatmap
middle = alt.hconcat(
    left_bar,
    heatmap
).resolve_scale(
    y='shared'
)

top_row = alt.hconcat(
    spacer,
    top_bar
)

# --- Final layout: top + (left + heatmap)
final_chart = alt.vconcat(
    top_row,
    middle
).resolve_scale(
    x='shared'
).configure_view(
    stroke=None  # Remove borders from all charts
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
# Select organization columns + Year
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
org_data = df[['Year'] + org_cols].copy()

# Melt to long format
org_long = org_data.melt(id_vars='Year', var_name='Organization', value_name='Attacked')

# Keep only incidents where that org was attacked (i.e., value == 1)
org_long = org_long[org_long['Attacked'] == 1]

# Group by Year and Organization
org_counts = org_long.groupby(['Year', 'Organization']).size().reset_index(name='Incident Count')

# %%
# Select organization columns + Year
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
org_data = df[['Year'] + org_cols].copy()

# Melt to long format
org_long = org_data.melt(id_vars='Year', var_name='Organization', value_name='Attacked')

# Keep only incidents where that org was attacked (i.e., value == 1)
org_long = org_long[org_long['Attacked'] == 1]

# Group by Year and Organization
org_counts = org_long.groupby(['Year', 'Organization']).size().reset_index(name='Incident Count')

chart = alt.Chart(org_counts).mark_line(point=True).encode(
    x=alt.X('Year:O', title='Year'),
    y=alt.Y('Incident Count:Q', title='Incidents'),
    color=alt.Color('Organization:N', title='Organization'),
    tooltip=['Year:O', 'Organization:N', 'Incident Count:Q']
).properties(
    width=600,
    height=400,
    title='Organization Attacks Over Time'
)

chart
# Out:
# alt.Chart(...)

# %%
national_cols = ['Nationals killed', 'Nationals wounded', 'Nationals kidnapped']
intl_cols = ['Internationals killed', 'Internationals wounded', 'Internationals kidnapped']
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']

# 1. Keep relevant columns
df_org = df[org_cols + national_cols + intl_cols].copy()

# 2. Add incident ID (or use index)
df_org['Incident ID'] = df.index

# 3. Melt impact data
impact_long = df_org.melt(
    id_vars=['Incident ID'] + org_cols,
    value_vars=national_cols + intl_cols,
    var_name='Impact Type',
    value_name='Count'
)

# 4. Remove zeros and NaNs
impact_long = impact_long[impact_long['Count'].fillna(0) > 0]

# 5. Tag impact as National/International
impact_long['Group'] = impact_long['Impact Type'].apply(
    lambda x: 'Nationals' if 'Nationals' in x else 'Internationals'
)

# 6. Melt organizations to long format
impact_long = impact_long.melt(
    id_vars=['Incident ID', 'Impact Type', 'Count', 'Group'],
    value_vars=org_cols,
    var_name='Organization',
    value_name='Involved'
)

# 7. Keep rows where the org was actually involved
impact_long = impact_long[impact_long['Involved'] == 1]

# 8. Group by Org + Impact Type
summary = impact_long.groupby(['Organization', 'Impact Type']).agg({'Count': 'sum'}).reset_index()

# %%
national_cols = ['Nationals killed', 'Nationals wounded', 'Nationals kidnapped']
intl_cols = ['Internationals killed', 'Internationals wounded', 'Internationals kidnapped']
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']

# 1. Keep relevant columns
df_org = df[org_cols + national_cols + intl_cols].copy()

# 2. Add incident ID (or use index)
df_org['Incident ID'] = df.index

# 3. Melt impact data
impact_long = df_org.melt(
    id_vars=['Incident ID'] + org_cols,
    value_vars=national_cols + intl_cols,
    var_name='Impact Type',
    value_name='Count'
)

# 4. Remove zeros and NaNs
impact_long = impact_long[impact_long['Count'].fillna(0) > 0]

# 5. Tag impact as National/International
impact_long['Group'] = impact_long['Impact Type'].apply(
    lambda x: 'Nationals' if 'Nationals' in x else 'Internationals'
)

# 6. Melt organizations to long format
impact_long = impact_long.melt(
    id_vars=['Incident ID', 'Impact Type', 'Count', 'Group'],
    value_vars=org_cols,
    var_name='Organization',
    value_name='Involved'
)

# 7. Keep rows where the org was actually involved
impact_long = impact_long[impact_long['Involved'] == 1]

# 8. Group by Org + Impact Type
summary = impact_long.groupby(['Organization', 'Impact Type']).agg({'Count': 'sum'}).reset_index()

chart = alt.Chart(summary).mark_bar().encode(
    x=alt.X('Organization:N', title='Organization'),
    y=alt.Y('Count:Q', title='Total Casualties'),
    color=alt.Color('Impact Type:N', title='Impact Type'),
    tooltip=['Organization:N', 'Impact Type:N', 'Count:Q']
).properties(
    width=600,
    height=400,
    title='Casualties by Organization and Impact Type'
)

chart
# Out:
# alt.Chart(...)

# %%
national_cols = ['Nationals killed', 'Nationals wounded', 'Nationals kidnapped']
intl_cols = ['Internationals killed', 'Internationals wounded', 'Internationals kidnapped']
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']

df_org = df[org_cols + national_cols + intl_cols].copy()

df_org['Incident ID'] = df.index

impact_long = df_org.melt(
    id_vars=['Incident ID'] + org_cols,
    value_vars=national_cols + intl_cols,
    var_name='Impact Type',
    value_name='Count'
)

# 4. Remove zeros and NaNs
impact_long = impact_long[impact_long['Count'].fillna(0) > 0]

# 5. Tag impact as National/International
impact_long['Group'] = impact_long['Impact Type'].apply(
    lambda x: 'Nationals' if 'Nationals' in x else 'Internationals'
)

# 6. Melt organizations to long format
impact_long = impact_long.melt(
    id_vars=['Incident ID', 'Impact Type', 'Count', 'Group'],
    value_vars=org_cols,
    var_name='Organization',
    value_name='Involved'
)

# 7. Keep rows where the org was actually involved
impact_long = impact_long[impact_long['Involved'] == 1]

# 8. Group by Org + Impact Type
summary = impact_long.groupby(['Organization', 'Impact Type']).agg({'Count': 'sum'}).reset_index()

grouped = impact_long.groupby(['Organization', 'Group', 'Impact Type']).agg({'Count': 'sum'}).reset_index()


chart = alt.Chart(grouped).mark_bar().encode(
    x=alt.X('Organization:N', title='Organization'),
    y=alt.Y('Count:Q', title='Total Casualties'),
    color=alt.Color('Impact Type:N', title='Impact Type'),
    column=alt.Column('Group:N', title='Group', sort=['Nationals', 'Internationals']),
    tooltip=['Organization:N', 'Impact Type:N', 'Count:Q']
).properties(
    width=150,
    height=400,
    title='Casualties by Organization: Nationals vs Internationals'
)

chart
# Out:
# alt.Chart(...)

# %%
national_cols = ['Nationals killed', 'Nationals wounded', 'Nationals kidnapped']
intl_cols = ['Internationals killed', 'Internationals wounded', 'Internationals kidnapped']
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']

df_org = df[org_cols + national_cols + intl_cols].copy()

df_org['Incident ID'] = df.index

impact_long = df_org.melt(
    id_vars=['Incident ID'] + org_cols,
    value_vars=national_cols + intl_cols,
    var_name='Impact Type',
    value_name='Count'
)

impact_long = impact_long[impact_long['Count'].fillna(0) > 0]

# 5. Tag impact as National/International
impact_long['Group'] = impact_long['Impact Type'].apply(
    lambda x: 'Nationals' if 'Nationals' in x else 'Internationals'
)

impact_long = impact_long.melt(
    id_vars=['Incident ID', 'Impact Type', 'Count', 'Group'],
    value_vars=org_cols,
    var_name='Organization',
    value_name='Involved'
)

# 7. Keep rows where the org was actually involved
impact_long = impact_long[impact_long['Involved'] == 1]

# 8. Group by Org + Impact Type
summary = impact_long.groupby(['Organization', 'Impact Type']).agg({'Count': 'sum'}).reset_index()

grouped = impact_long.groupby(['Organization', 'Group', 'Impact Type']).agg({'Count': 'sum'}).reset_index()

# Simplify impact type (remove group prefix)
impact_long['Impact Simple'] = impact_long['Impact Type'].str.extract(r'(killed|wounded|kidnapped)', expand=False).str.capitalize()

# Group and summarize
stacked_data = impact_long.groupby(['Organization', 'Group', 'Impact Simple']).agg({'Count': 'sum'}).reset_index()


chart = alt.Chart(stacked_data).mark_bar().encode(
    x=alt.X('Organization:N', title='Organization'),
    y=alt.Y('Count:Q', title='Total Casualties'),
    color=alt.Color('Impact Simple:N', title='Impact Type', scale=alt.Scale(scheme='set1')),
    xOffset=alt.XOffset('Group:N', title='Group'),
    tooltip=['Organization:N', 'Group:N', 'Impact Simple:N', 'Count:Q']
).properties(
    width=600,
    height=400,
    title='Casualties by Organization (Nationals vs Internationals)'
)

chart
# Out:
# alt.Chart(...)

# %%
national_cols = ['Nationals killed', 'Nationals wounded', 'Nationals kidnapped']
intl_cols = ['Internationals killed', 'Internationals wounded', 'Internationals kidnapped']
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']

df_org = df[org_cols + national_cols + intl_cols].copy()

df_org['Incident ID'] = df.index

impact_long = df_org.melt(
    id_vars=['Incident ID'] + org_cols,
    value_vars=national_cols + intl_cols,
    var_name='Impact Type',
    value_name='Count'
)

impact_long = impact_long[impact_long['Count'].fillna(0) > 0]

# 5. Tag impact as National/International
impact_long['Group'] = impact_long['Impact Type'].apply(
    lambda x: 'Nationals' if 'Nationals' in x else 'Internationals'
)

impact_long = impact_long.melt(
    id_vars=['Incident ID', 'Impact Type', 'Count', 'Group'],
    value_vars=org_cols,
    var_name='Organization',
    value_name='Involved'
)

# Simplify impact type (remove group prefix)
impact_long['Impact Simple'] = impact_long['Impact Type'].str.extract(r'(killed|wounded|kidnapped)', expand=False).str.capitalize()

# Group and summarize
stacked_data = impact_long.groupby(['Organization', 'Group', 'Impact Simple']).agg({'Count': 'sum'}).reset_index()


chart = alt.Chart(stacked_data).mark_bar().encode(
    x=alt.X('Organization:N', title='Organization'),
    y=alt.Y('Count:Q', title='Total Casualties'),
    color=alt.Color('Impact Simple:N', title='Impact Type', scale=alt.Scale(scheme='set1')),
    xOffset=alt.XOffset('Group:N', title='Group'),
    tooltip=['Organization:N', 'Group:N', 'Impact Simple:N', 'Count:Q']
).properties(
    width=600,
    height=400,
    title='Casualties by Organization (Nationals vs Internationals)'
)

chart
# Out:
# alt.Chart(...)

# %%
national_cols = ['Nationals killed', 'Nationals wounded', 'Nationals kidnapped']
intl_cols = ['Internationals killed', 'Internationals wounded', 'Internationals kidnapped']
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']

df_org = df[org_cols + national_cols + intl_cols].copy()

df_org['Incident ID'] = df.index

impact_long = df_org.melt(
    id_vars=['Incident ID'] + org_cols,
    value_vars=national_cols + intl_cols,
    var_name='Impact Type',
    value_name='Count'
)

impact_long = impact_long[impact_long['Count'].fillna(0) > 0]

# 5. Tag impact as National/International
impact_long['Group'] = impact_long['Impact Type'].apply(
    lambda x: 'Nationals' if 'Nationals' in x else 'Internationals'
)

impact_long = impact_long.melt(
    id_vars=['Incident ID', 'Impact Type', 'Count', 'Group'],
    value_vars=org_cols,
    var_name='Organization',
    value_name='Involved'
)

# 7. Keep rows where the org was actually involved
impact_long = impact_long[impact_long['Involved'] == 1]

grouped = impact_long.groupby(['Organization', 'Group', 'Impact Type']).agg({'Count': 'sum'}).reset_index()

# Simplify impact type (remove group prefix)
impact_long['Impact Simple'] = impact_long['Impact Type'].str.extract(r'(killed|wounded|kidnapped)', expand=False).str.capitalize()

# Group and summarize
stacked_data = impact_long.groupby(['Organization', 'Group', 'Impact Simple']).agg({'Count': 'sum'}).reset_index()


chart = alt.Chart(stacked_data).mark_bar().encode(
    x=alt.X('Organization:N', title='Organization'),
    y=alt.Y('Count:Q', title='Total Casualties'),
    color=alt.Color('Impact Simple:N', title='Impact Type', scale=alt.Scale(scheme='set1')),
    xOffset=alt.XOffset('Group:N', title='Group'),
    tooltip=['Organization:N', 'Group:N', 'Impact Simple:N', 'Count:Q']
).properties(
    width=600,
    height=400,
    title='Casualties by Organization (Nationals vs Internationals)'
)

chart
# Out:
# alt.Chart(...)

# %%
national_cols = ['Nationals killed', 'Nationals wounded', 'Nationals kidnapped']
intl_cols = ['Internationals killed', 'Internationals wounded', 'Internationals kidnapped']
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']

df_org = df[org_cols + national_cols + intl_cols].copy()

df_org['Incident ID'] = df.index

impact_long = df_org.melt(
    id_vars=['Incident ID'] + org_cols,
    value_vars=national_cols + intl_cols,
    var_name='Impact Type',
    value_name='Count'
)

impact_long = impact_long[impact_long['Count'].fillna(0) > 0]

# 5. Tag impact as National/International
impact_long['Group'] = impact_long['Impact Type'].apply(
    lambda x: 'Nationals' if 'Nationals' in x else 'Internationals'
)

impact_long = impact_long.melt(
    id_vars=['Incident ID', 'Impact Type', 'Count', 'Group'],
    value_vars=org_cols,
    var_name='Organization',
    value_name='Involved'
)

# 7. Keep rows where the org was actually involved
impact_long = impact_long[impact_long['Involved'] == 1]

grouped = impact_long.groupby(['Organization', 'Group', 'Impact Type']).agg({'Count': 'sum'}).reset_index()

# Simplify impact type (remove group prefix)
impact_long['Impact Simple'] = impact_long['Impact Type'].str.extract(r'(killed|wounded|kidnapped)', expand=False).str.capitalize()

# Group and summarize
stacked_data = impact_long.groupby(['Organization', 'Group', 'Impact Simple']).agg({'Count': 'sum'}).reset_index()


chart = alt.Chart(stacked_data).mark_bar().encode(
    x=alt.X('Organization:N', title='Organization'),
    y=alt.Y('Count:Q', title='Total Casualties'),
    color=alt.Color('Impact Simple:N', title='Impact Type', scale=alt.Scale(scheme='set2')),
    xOffset=alt.XOffset('Group:N', title='Group'),
    tooltip=['Organization:N', 'Group:N', 'Impact Simple:N', 'Count:Q']
).properties(
    width=600,
    height=400,
    title='Casualties by Organization (Nationals vs Internationals)'
)

chart
# Out:
# alt.Chart(...)

# %%
national_cols = ['Nationals killed', 'Nationals wounded', 'Nationals kidnapped']
intl_cols = ['Internationals killed', 'Internationals wounded', 'Internationals kidnapped']
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']

df_org = df[org_cols + national_cols + intl_cols].copy()

df_org['Incident ID'] = df.index

impact_long = df_org.melt(
    id_vars=['Incident ID'] + org_cols,
    value_vars=national_cols + intl_cols,
    var_name='Impact Type',
    value_name='Count'
)

impact_long = impact_long[impact_long['Count'].fillna(0) > 0]

# 5. Tag impact as National/International
impact_long['Group'] = impact_long['Impact Type'].apply(
    lambda x: 'Nationals' if 'Nationals' in x else 'Internationals'
)

impact_long = impact_long.melt(
    id_vars=['Incident ID', 'Impact Type', 'Count', 'Group'],
    value_vars=org_cols,
    var_name='Organization',
    value_name='Involved'
)

# 7. Keep rows where the org was actually involved
impact_long = impact_long[impact_long['Involved'] == 1]

grouped = impact_long.groupby(['Organization', 'Group', 'Impact Type']).agg({'Count': 'sum'}).reset_index()

# Simplify impact type (remove group prefix)
impact_long['Impact Simple'] = impact_long['Impact Type'].str.extract(r'(killed|wounded|kidnapped)', expand=False).str.capitalize()

# Group and summarize
stacked_data = impact_long.groupby(['Organization', 'Group', 'Impact Simple']).agg({'Count': 'sum'}).reset_index()


chart = alt.Chart(stacked_data).mark_bar().encode(
    x=alt.X('Organization:N', title='Organization'),
    y=alt.Y('Count:Q', title='Total Casualties'),
    color=alt.Color('Impact Simple:N', title='Impact Type', scale=alt.Scale(scheme='set3')),
    xOffset=alt.XOffset('Group:N', title='Group'),
    tooltip=['Organization:N', 'Group:N', 'Impact Simple:N', 'Count:Q']
).properties(
    width=600,
    height=400,
    title='Casualties by Organization (Nationals vs Internationals)'
)

chart
# Out:
# alt.Chart(...)

# %%
national_cols = ['Nationals killed', 'Nationals wounded', 'Nationals kidnapped']
intl_cols = ['Internationals killed', 'Internationals wounded', 'Internationals kidnapped']
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']

df_org = df[org_cols + national_cols + intl_cols].copy()

df_org['Incident ID'] = df.index

impact_long = df_org.melt(
    id_vars=['Incident ID'] + org_cols,
    value_vars=national_cols + intl_cols,
    var_name='Impact Type',
    value_name='Count'
)

impact_long = impact_long[impact_long['Count'].fillna(0) > 0]

# 5. Tag impact as National/International
impact_long['Group'] = impact_long['Impact Type'].apply(
    lambda x: 'Nationals' if 'Nationals' in x else 'Internationals'
)

impact_long = impact_long.melt(
    id_vars=['Incident ID', 'Impact Type', 'Count', 'Group'],
    value_vars=org_cols,
    var_name='Organization',
    value_name='Involved'
)

# 7. Keep rows where the org was actually involved
impact_long = impact_long[impact_long['Involved'] == 1]

grouped = impact_long.groupby(['Organization', 'Group', 'Impact Type']).agg({'Count': 'sum'}).reset_index()

# Simplify impact type (remove group prefix)
impact_long['Impact Simple'] = impact_long['Impact Type'].str.extract(r'(killed|wounded|kidnapped)', expand=False).str.capitalize()

# Group and summarize
stacked_data = impact_long.groupby(['Organization', 'Group', 'Impact Simple']).agg({'Count': 'sum'}).reset_index()


chart = alt.Chart(stacked_data).mark_bar().encode(
    x=alt.X('Organization:N', title='Organization'),
    y=alt.Y('Count:Q', title='Total Casualties'),
    color=alt.Color('Impact Simple:N', title='Impact Type', scale=alt.Scale(scheme='set4')),
    xOffset=alt.XOffset('Group:N', title='Group'),
    tooltip=['Organization:N', 'Group:N', 'Impact Simple:N', 'Count:Q']
).properties(
    width=600,
    height=400,
    title='Casualties by Organization (Nationals vs Internationals)'
)

chart
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# ~/mini_project/python.qmd in <module>
#      43     x=alt.X('Organization:N', title='Organization'),
#      44     y=alt.Y('Count:Q', title='Total Casualties'),
# ---> 45     color=alt.Color('Impact Simple:N', title='Impact Type', scale=alt.Scale(scheme='set4')),
#      46     xOffset=alt.XOffset('Group:N', title='Group'),
#      47     tooltip=['Organization:N', 'Group:N', 'Impact Simple:N', 'Count:Q']
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/schema/core.py in __init__(self, align, base, bins, clamp, constant, domain, domainMax, domainMid, domainMin, domainRaw, exponent, interpolate, nice, padding, paddingInner, paddingOuter, range, rangeMax, rangeMin, reverse, round, scheme, type, zero, **kwds)
#   18344         **kwds,
#   18345     ):
# > 18346         super().__init__(
#   18347             align=align,
#   18348             base=base,
#
# ~/.local/lib/python3.10/site-packages/altair/utils/schemapi.py in __init__(self, *args, **kwds)
#    1041
#    1042         if DEBUG_MODE and self._class_is_valid_at_instantiation:
# -> 1043             self.to_dict(validate=True)
#    1044
#    1045     def copy(
#
# ~/.local/lib/python3.10/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#    1167                 self.validate(result)
#    1168             except jsonschema.ValidationError as err:
# -> 1169                 raise SchemaValidationError(self, err) from None
#    1170         return result
#    1171
#
# SchemaValidationError: 'set4' is an invalid value for `scheme`. Valid values are:
#
# - One of ['accent', 'category10', 'category20', 'category20b', 'category20c', 'dark2', 'paired', 'pastel1', 'pastel2', 'set1', 'set2', 'set3', 'tableau10', 'tableau20']
# - One of ['blues', 'tealblues', 'teals', 'greens', 'browns', 'greys', 'purples', 'warmgreys', 'reds', 'oranges']
# - One of ['turbo', 'viridis', 'inferno', 'magma', 'plasma', 'cividis', 'bluegreen', 'bluegreen-3', 'bluegreen-4', 'bluegreen-5', 'bluegreen-6', 'bluegreen-7', 'bluegreen-8', 'bluegreen-9', 'bluepurple', 'bluepurple-3', 'bluepurple-4', 'bluepurple-5', 'bluepurple-6', 'bluepurple-7', 'bluepurple-8', 'bluepurple-9', 'goldgreen', 'goldgreen-3', 'goldgreen-4', 'goldgreen-5', 'goldgreen-6', 'goldgreen-7', 'goldgreen-8', 'goldgreen-9', 'goldorange', 'goldorange-3', 'goldorange-4', 'goldorange-5', 'goldorange-6', 'goldorange-7', 'goldorange-8', 'goldorange-9', 'goldred', 'goldred-3', 'goldred-4', 'goldred-5', 'goldred-6', 'goldred-7', 'goldred-8', 'goldred-9', 'greenblue', 'greenblue-3', 'greenblue-4', 'greenblue-5', 'greenblue-6', 'greenblue-7', 'greenblue-8', 'greenblue-9', 'orangered', 'orangered-3', 'orangered-4', 'orangered-5', 'orangered-6', 'orangered-7', 'orangered-8', 'orangered-9', 'purplebluegreen', 'purplebluegreen-3', 'purplebluegreen-4', 'purplebluegreen-5', 'purplebluegreen-6', 'purplebluegreen-7', 'purplebluegreen-8', 'purplebluegreen-9', 'purpleblue', 'purpleblue-3', 'purpleblue-4', 'purpleblue-5', 'purpleblue-6', 'purpleblue-7', 'purpleblue-8', 'purpleblue-9', 'purplered', 'purplered-3', 'purplered-4', 'purplered-5', 'purplered-6', 'purplered-7', 'purplered-8', 'purplered-9', 'redpurple', 'redpurple-3', 'redpurple-4', 'redpurple-5', 'redpurple-6', 'redpurple-7', 'redpurple-8', 'redpurple-9', 'yellowgreenblue', 'yellowgreenblue-3', 'yellowgreenblue-4', 'yellowgreenblue-5', 'yellowgreenblue-6', 'yellowgreenblue-7', 'yellowgreenblue-8', 'yellowgreenblue-9', 'yellowgreen', 'yellowgreen-3', 'yellowgreen-4', 'yellowgreen-5', 'yellowgreen-6', 'yellowgreen-7', 'yellowgreen-8', 'yellowgreen-9', 'yelloworangebrown', 'yelloworangebrown-3', 'yelloworangebrown-4', 'yelloworangebrown-5', 'yelloworangebrown-6', 'yelloworangebrown-7', 'yelloworangebrown-8', 'yelloworangebrown-9', 'yelloworangered', 'yelloworangered-3', 'yelloworangered-4', 'yelloworangered-5', 'yelloworangered-6', 'yelloworangered-7', 'yelloworangered-8', 'yelloworangered-9', 'darkblue', 'darkblue-3', 'darkblue-4', 'darkblue-5', 'darkblue-6', 'darkblue-7', 'darkblue-8', 'darkblue-9', 'darkgold', 'darkgold-3', 'darkgold-4', 'darkgold-5', 'darkgold-6', 'darkgold-7', 'darkgold-8', 'darkgold-9', 'darkgreen', 'darkgreen-3', 'darkgreen-4', 'darkgreen-5', 'darkgreen-6', 'darkgreen-7', 'darkgreen-8', 'darkgreen-9', 'darkmulti', 'darkmulti-3', 'darkmulti-4', 'darkmulti-5', 'darkmulti-6', 'darkmulti-7', 'darkmulti-8', 'darkmulti-9', 'darkred', 'darkred-3', 'darkred-4', 'darkred-5', 'darkred-6', 'darkred-7', 'darkred-8', 'darkred-9', 'lightgreyred', 'lightgreyred-3', 'lightgreyred-4', 'lightgreyred-5', 'lightgreyred-6', 'lightgreyred-7', 'lightgreyred-8', 'lightgreyred-9', 'lightgreyteal', 'lightgreyteal-3', 'lightgreyteal-4', 'lightgreyteal-5', 'lightgreyteal-6', 'lightgreyteal-7', 'lightgreyteal-8', 'lightgreyteal-9', 'lightmulti', 'lightmulti-3', 'lightmulti-4', 'lightmulti-5', 'lightmulti-6', 'lightmulti-7', 'lightmulti-8', 'lightmulti-9', 'lightorange', 'lightorange-3', 'lightorange-4', 'lightorange-5', 'lightorange-6', 'lightorange-7', 'lightorange-8', 'lightorange-9', 'lighttealblue', 'lighttealblue-3', 'lighttealblue-4', 'lighttealblue-5', 'lighttealblue-6', 'lighttealblue-7', 'lighttealblue-8', 'lighttealblue-9']
# - One of ['blueorange', 'blueorange-3', 'blueorange-4', 'blueorange-5', 'blueorange-6', 'blueorange-7', 'blueorange-8', 'blueorange-9', 'blueorange-10', 'blueorange-11', 'brownbluegreen', 'brownbluegreen-3', 'brownbluegreen-4', 'brownbluegreen-5', 'brownbluegreen-6', 'brownbluegreen-7', 'brownbluegreen-8', 'brownbluegreen-9', 'brownbluegreen-10', 'brownbluegreen-11', 'purplegreen', 'purplegreen-3', 'purplegreen-4', 'purplegreen-5', 'purplegreen-6', 'purplegreen-7', 'purplegreen-8', 'purplegreen-9', 'purplegreen-10', 'purplegreen-11', 'pinkyellowgreen', 'pinkyellowgreen-3', 'pinkyellowgreen-4', 'pinkyellowgreen-5', 'pinkyellowgreen-6', 'pinkyellowgreen-7', 'pinkyellowgreen-8', 'pinkyellowgreen-9', 'pinkyellowgreen-10', 'pinkyellowgreen-11', 'purpleorange', 'purpleorange-3', 'purpleorange-4', 'purpleorange-5', 'purpleorange-6', 'purpleorange-7', 'purpleorange-8', 'purpleorange-9', 'purpleorange-10', 'purpleorange-11', 'redblue', 'redblue-3', 'redblue-4', 'redblue-5', 'redblue-6', 'redblue-7', 'redblue-8', 'redblue-9', 'redblue-10', 'redblue-11', 'redgrey', 'redgrey-3', 'redgrey-4', 'redgrey-5', 'redgrey-6', 'redgrey-7', 'redgrey-8', 'redgrey-9', 'redgrey-10', 'redgrey-11', 'redyellowblue', 'redyellowblue-3', 'redyellowblue-4', 'redyellowblue-5', 'redyellowblue-6', 'redyellowblue-7', 'redyellowblue-8', 'redyellowblue-9', 'redyellowblue-10', 'redyellowblue-11', 'redyellowgreen', 'redyellowgreen-3', 'redyellowgreen-4', 'redyellowgreen-5', 'redyellowgreen-6', 'redyellowgreen-7', 'redyellowgreen-8', 'redyellowgreen-9', 'redyellowgreen-10', 'redyellowgreen-11', 'spectral', 'spectral-3', 'spectral-4', 'spectral-5', 'spectral-6', 'spectral-7', 'spectral-8', 'spectral-9', 'spectral-10', 'spectral-11']
# - One of ['rainbow', 'sinebow']
# - Of type 'object'

# %%
national_cols = ['Nationals killed', 'Nationals wounded', 'Nationals kidnapped']
intl_cols = ['Internationals killed', 'Internationals wounded', 'Internationals kidnapped']
org_cols = ['UN', 'INGO', 'ICRC', 'NRCS and IFRC', 'NNGO', 'Other']

df_org = df[org_cols + national_cols + intl_cols].copy()

df_org['Incident ID'] = df.index

impact_long = df_org.melt(
    id_vars=['Incident ID'] + org_cols,
    value_vars=national_cols + intl_cols,
    var_name='Impact Type',
    value_name='Count'
)

impact_long = impact_long[impact_long['Count'].fillna(0) > 0]

# 5. Tag impact as National/International
impact_long['Group'] = impact_long['Impact Type'].apply(
    lambda x: 'Nationals' if 'Nationals' in x else 'Internationals'
)

impact_long = impact_long.melt(
    id_vars=['Incident ID', 'Impact Type', 'Count', 'Group'],
    value_vars=org_cols,
    var_name='Organization',
    value_name='Involved'
)

# 7. Keep rows where the org was actually involved
impact_long = impact_long[impact_long['Involved'] == 1]

grouped = impact_long.groupby(['Organization', 'Group', 'Impact Type']).agg({'Count': 'sum'}).reset_index()

# Simplify impact type (remove group prefix)
impact_long['Impact Simple'] = impact_long['Impact Type'].str.extract(r'(killed|wounded|kidnapped)', expand=False).str.capitalize()

# Group and summarize
stacked_data = impact_long.groupby(['Organization', 'Group', 'Impact Simple']).agg({'Count': 'sum'}).reset_index()


chart = alt.Chart(stacked_data).mark_bar().encode(
    x=alt.X('Organization:N', title='Organization'),
    y=alt.Y('Count:Q', title='Total Casualties'),
    color=alt.Color('Impact Simple:N', title='Impact Type', scale=alt.Scale(scheme='set2')),
    xOffset=alt.XOffset('Group:N', title='Group'),
    tooltip=['Organization:N', 'Group:N', 'Impact Simple:N', 'Count:Q']
).properties(
    width=600,
    height=400,
    title='Casualties by Organization (Nationals vs Internationals)'
)

chart
# Out:
# alt.Chart(...)

# %%
# Sum across all incidents
gender_counts = df[['Gender Male', 'Gender Female', 'Gender Unknown']].sum().reset_index()
gender_counts.columns = ['Gender', 'Count']

# Clean gender labels
gender_counts['Gender'] = gender_counts['Gender'].str.replace('Gender ', '')

# Calculate percentage
gender_counts['Percent'] = gender_counts['Count'] / gender_counts['Count'].sum() * 100

# Round down to integer number of icons (1 icon = 1%)
gender_counts['Icons'] = (gender_counts['Percent'] // 1).astype(int)

# Expand to one row per icon
expanded = gender_counts.loc[gender_counts.index.repeat(gender_counts['Icons'])].reset_index(drop=True)
expanded['Icon ID'] = expanded.groupby('Gender').cumcount()

# Position in grid
expanded['Column'] = expanded['Icon ID'] % 10
expanded['Row'] = expanded['Icon ID'] // 10

# Map to emojis or icon symbols
icon_map = {'Male': '👨', 'Female': '👩', 'Unknown': '❓'}
expanded['Icon'] = expanded['Gender'].map(icon_map)

# Plot the grid
chart = alt.Chart(expanded).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', legend=alt.Legend(title='Gender'))
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (1 icon ≈ 1%)'
)

chart
# Out:
# alt.Chart(...)

# %%
# Sum across all incidents
gender_counts = df[['Gender Male', 'Gender Female', 'Gender Unknown']].sum().reset_index()
gender_counts.columns = ['Gender', 'Count']

# Clean gender labels
gender_counts['Gender'] = gender_counts['Gender'].str.replace('Gender ', '')

# Calculate percentage
gender_counts['Percent'] = gender_counts['Count'] / gender_counts['Count'].sum() * 100

# Round down to integer number of icons (1 icon = 1%)
gender_counts['Icons'] = (gender_counts['Percent'] // 1).astype(int)

gender_counts
# Out:
#     Gender  Count    Percent  Icons
# 0     Male   3859  47.152981     47
# 1   Female    602   7.355816      7
# 2  Unknown   3723  45.491202     45

# %%
# Expand: one row per icon
expanded = gender_counts.loc[gender_counts.index.repeat(gender_counts['Icons'])].reset_index(drop=True)
expanded['Icon ID'] = expanded.groupby('Gender').cumcount()

# Position in grid (10 columns)
expanded['Column'] = expanded['Icon ID'] % 10
expanded['Row'] = expanded['Icon ID'] // 10

# Set same icon for all
expanded['Icon'] = '👤'  # You can also use '■' for squares or '●' for circles

# Plot the grid
chart = alt.Chart(expanded).mark_text(
    fontSize=20
).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text=alt.Text('Icon:N'),
    color=alt.Color('Gender:N', legend=alt.Legend(title='Gender'))
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (1 icon ≈ 1%)'
)

chart
# Out:
# alt.Chart(...)

# %%
# Expand: one row per icon
expanded = gender_counts.loc[gender_counts.index.repeat(gender_counts['Icons'])].reset_index(drop=True)
expanded['Icon ID'] = expanded.groupby('Gender').cumcount()

# Position in grid (10 columns)
expanded['Column'] = expanded['Icon ID'] % 10
expanded['Row'] = expanded['Icon ID'] // 10

# Set same icon for all
expanded['Icon'] = '●'  # You can also use '■' for squares or '●' for circles

# Plot the grid
chart = alt.Chart(expanded).mark_text(
    fontSize=20
).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text=alt.Text('Icon:N'),
    color=alt.Color('Gender:N', legend=alt.Legend(title='Gender'))
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (1 icon ≈ 1%)'
)

chart
# Out:
# alt.Chart(...)

# %%
# Expand: one row per icon
expanded = gender_counts.loc[gender_counts.index.repeat(gender_counts['Icons'])].reset_index(drop=True)
expanded['Icon ID'] = expanded.groupby('Gender').cumcount()

# Position in grid (10 columns)
expanded['Column'] = expanded['Icon ID'] % 10
expanded['Row'] = expanded['Icon ID'] // 10

# Set same icon for all
expanded['Icon'] = '●'  # You can also use '■' for squares or '●' for circles

expanded
# Out:
#      Gender  Count    Percent  Icons  Icon ID  Column  Row Icon
# 0      Male   3859  47.152981     47        0       0    0    ●
# 1      Male   3859  47.152981     47        1       1    0    ●
# 2      Male   3859  47.152981     47        2       2    0    ●
# 3      Male   3859  47.152981     47        3       3    0    ●
# 4      Male   3859  47.152981     47        4       4    0    ●
# ..      ...    ...        ...    ...      ...     ...  ...  ...
# 94  Unknown   3723  45.491202     45       40       0    4    ●
# 95  Unknown   3723  45.491202     45       41       1    4    ●
# 96  Unknown   3723  45.491202     45       42       2    4    ●
# 97  Unknown   3723  45.491202     45       43       3    4    ●
# 98  Unknown   3723  45.491202     45       44       4    4    ●
#
# [99 rows x 8 columns]

# %%
import numpy as np

# 1. Start with the same counts
gender_counts = df[['Gender Male', 'Gender Female', 'Gender Unknown']].sum().reset_index()
gender_counts.columns = ['Gender', 'Count']
gender_counts['Gender'] = gender_counts['Gender'].str.replace('Gender ', '')
gender_counts['Percent'] = gender_counts['Count'] / gender_counts['Count'].sum() * 100

# 2. Floor the percentages
gender_counts['Icons'] = np.floor(gender_counts['Percent']).astype(int)

# 3. Calculate how many icons we're short
icons_needed = 100 - gender_counts['Icons'].sum()

# 4. Compute fractional parts to distribute remaining icons
gender_counts['Fraction'] = gender_counts['Percent'] - gender_counts['Icons']

# 5. Add 1 icon to the rows with largest fractional parts
gender_counts.loc[gender_counts.sort_values('Fraction', ascending=False).head(icons_needed).index, 'Icons'] += 1

# Drop helper column
gender_counts.drop(columns='Fraction', inplace=True)

# %%
import numpy as np

# 1. Start with the same counts
gender_counts = df[['Gender Male', 'Gender Female', 'Gender Unknown']].sum().reset_index()
gender_counts.columns = ['Gender', 'Count']
gender_counts['Gender'] = gender_counts['Gender'].str.replace('Gender ', '')
gender_counts['Percent'] = gender_counts['Count'] / gender_counts['Count'].sum() * 100

# 2. Floor the percentages
gender_counts['Icons'] = np.floor(gender_counts['Percent']).astype(int)

# 3. Calculate how many icons we're short
icons_needed = 100 - gender_counts['Icons'].sum()

# 4. Compute fractional parts to distribute remaining icons
gender_counts['Fraction'] = gender_counts['Percent'] - gender_counts['Icons']

# 5. Add 1 icon to the rows with largest fractional parts
gender_counts.loc[gender_counts.sort_values('Fraction', ascending=False).head(icons_needed).index, 'Icons'] += 1

# Drop helper column
gender_counts.drop(columns='Fraction', inplace=True)

gender_counts
# Out:
#     Gender  Count    Percent  Icons
# 0     Male   3859  47.152981     47
# 1   Female    602   7.355816      7
# 2  Unknown   3723  45.491202     46

# %%
# Expand to one row per icon
expanded = gender_counts.loc[gender_counts.index.repeat(gender_counts['Icons'])].reset_index(drop=True)
expanded['Icon ID'] = expanded.groupby('Gender').cumcount()
expanded['Column'] = expanded['Icon ID'] % 10
expanded['Row'] = expanded['Icon ID'] // 10
expanded['Icon'] = '👤'  # or '■'

expanded
# Out:
#      Gender  Count    Percent  Icons  Icon ID  Column  Row Icon
# 0      Male   3859  47.152981     47        0       0    0    👤
# 1      Male   3859  47.152981     47        1       1    0    👤
# 2      Male   3859  47.152981     47        2       2    0    👤
# 3      Male   3859  47.152981     47        3       3    0    👤
# 4      Male   3859  47.152981     47        4       4    0    👤
# ..      ...    ...        ...    ...      ...     ...  ...  ...
# 95  Unknown   3723  45.491202     46       41       1    4    👤
# 96  Unknown   3723  45.491202     46       42       2    4    👤
# 97  Unknown   3723  45.491202     46       43       3    4    👤
# 98  Unknown   3723  45.491202     46       44       4    4    👤
# 99  Unknown   3723  45.491202     46       45       5    4    👤
#
# [100 rows x 8 columns]

# %%
# Plot the grid
chart = alt.Chart(expanded).mark_text(
    fontSize=20
).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text=alt.Text('Icon:N'),
    color=alt.Color('Gender:N', legend=alt.Legend(title='Gender'))
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (Each icon = 1%)'
)

chart
# Out:
# alt.Chart(...)

# %%
# Expand to one row per icon
expanded = gender_counts.loc[gender_counts.index.repeat(gender_counts['Icons'])].reset_index(drop=True)
expanded['Icon ID'] = expanded.groupby('Gender').cumcount()
expanded['Column'] = expanded['Icon ID'] % 10
expanded['Row'] = expanded['Icon ID'] // 10
expanded['Icon'] = '●'  # or '■'

expanded
# Out:
#      Gender  Count    Percent  Icons  Icon ID  Column  Row Icon
# 0      Male   3859  47.152981     47        0       0    0    ●
# 1      Male   3859  47.152981     47        1       1    0    ●
# 2      Male   3859  47.152981     47        2       2    0    ●
# 3      Male   3859  47.152981     47        3       3    0    ●
# 4      Male   3859  47.152981     47        4       4    0    ●
# ..      ...    ...        ...    ...      ...     ...  ...  ...
# 95  Unknown   3723  45.491202     46       41       1    4    ●
# 96  Unknown   3723  45.491202     46       42       2    4    ●
# 97  Unknown   3723  45.491202     46       43       3    4    ●
# 98  Unknown   3723  45.491202     46       44       4    4    ●
# 99  Unknown   3723  45.491202     46       45       5    4    ●
#
# [100 rows x 8 columns]

# %%
# Plot the grid
chart = alt.Chart(expanded).mark_text(
    fontSize=20
).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text=alt.Text('Icon:N'),
    color=alt.Color('Gender:N', legend=alt.Legend(title='Gender'))
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (Each icon = 1%)'
)

chart
# Out:
# alt.Chart(...)

# %%
import numpy as np

# 1. Start with the same counts
gender_counts = df[['Gender Male', 'Gender Female', 'Gender Unknown']].sum().reset_index()
gender_counts.columns = ['Gender', 'Count']
gender_counts['Gender'] = gender_counts['Gender'].str.replace('Gender ', '')
gender_counts['Percent'] = gender_counts['Count'] / gender_counts['Count'].sum() * 100

# 2. Floor the percentages
gender_counts['Icons'] = np.floor(gender_counts['Percent']).astype(int)

# 3. Calculate how many icons we're short
icons_needed = 100 - gender_counts['Icons'].sum()

# 4. Compute fractional parts to distribute remaining icons
gender_counts['Fraction'] = gender_counts['Percent'] - gender_counts['Icons']

# 5. Add 1 icon to the rows with largest fractional parts
gender_counts.loc[gender_counts.sort_values('Fraction', ascending=False).head(icons_needed).index, 'Icons'] += 1

# Drop helper column
gender_counts.drop(columns='Fraction', inplace=True)

assert gender_counts['Icons'].sum() == 100, "Icon count must be exactly 100"

# %%
# Expand to one row per icon
icons_df = gender_counts.loc[gender_counts.index.repeat(gender_counts['Icons'])].reset_index(drop=True)

# Position in a 10x10 grid
icons_df['Index'] = icons_df.index
icons_df['Column'] = icons_df['Index'] % 10
icons_df['Row'] = icons_df['Index'] // 10
icons_df['Icon'] = '👤'  # or '⬤', '■'
icons_df
# Out:
#      Gender  Count    Percent  Icons  Index  Column  Row Icon
# 0      Male   3859  47.152981     47      0       0    0    👤
# 1      Male   3859  47.152981     47      1       1    0    👤
# 2      Male   3859  47.152981     47      2       2    0    👤
# 3      Male   3859  47.152981     47      3       3    0    👤
# 4      Male   3859  47.152981     47      4       4    0    👤
# ..      ...    ...        ...    ...    ...     ...  ...  ...
# 95  Unknown   3723  45.491202     46     95       5    9    👤
# 96  Unknown   3723  45.491202     46     96       6    9    👤
# 97  Unknown   3723  45.491202     46     97       7    9    👤
# 98  Unknown   3723  45.491202     46     98       8    9    👤
# 99  Unknown   3723  45.491202     46     99       9    9    👤
#
# [100 rows x 8 columns]

# %%
# Expand to one row per icon
icons_df = gender_counts.loc[gender_counts.index.repeat(gender_counts['Icons'])].reset_index(drop=True)

# Position in a 10x10 grid
icons_df['Index'] = icons_df.index
icons_df['Column'] = icons_df['Index'] % 10
icons_df['Row'] = icons_df['Index'] // 10
icons_df['Icon'] = '👤'  # or '⬤', '■'
icons_df
# Out:
#      Gender  Count    Percent  Icons  Index  Column  Row Icon
# 0      Male   3859  47.152981     47      0       0    0    👤
# 1      Male   3859  47.152981     47      1       1    0    👤
# 2      Male   3859  47.152981     47      2       2    0    👤
# 3      Male   3859  47.152981     47      3       3    0    👤
# 4      Male   3859  47.152981     47      4       4    0    👤
# ..      ...    ...        ...    ...    ...     ...  ...  ...
# 95  Unknown   3723  45.491202     46     95       5    9    👤
# 96  Unknown   3723  45.491202     46     96       6    9    👤
# 97  Unknown   3723  45.491202     46     97       7    9    👤
# 98  Unknown   3723  45.491202     46     98       8    9    👤
# 99  Unknown   3723  45.491202     46     99       9    9    👤
#
# [100 rows x 8 columns]

# %%
# Plot the grid
chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (Each 👤 = 1%)'
).configure_view(
    stroke=None
)

chart
# Out:
# alt.Chart(...)

# %%
# Expand to one row per icon
icons_df = gender_counts.loc[gender_counts.index.repeat(gender_counts['Icons'])].reset_index(drop=True)

# Position in a 10x10 grid
icons_df['Index'] = icons_df.index
icons_df['Column'] = icons_df['Index'] % 10
icons_df['Row'] = icons_df['Index'] // 10
icons_df['Icon'] = '⬤'  # or '⬤', '■'
icons_df
# Out:
#      Gender  Count    Percent  Icons  Index  Column  Row Icon
# 0      Male   3859  47.152981     47      0       0    0    ⬤
# 1      Male   3859  47.152981     47      1       1    0    ⬤
# 2      Male   3859  47.152981     47      2       2    0    ⬤
# 3      Male   3859  47.152981     47      3       3    0    ⬤
# 4      Male   3859  47.152981     47      4       4    0    ⬤
# ..      ...    ...        ...    ...    ...     ...  ...  ...
# 95  Unknown   3723  45.491202     46     95       5    9    ⬤
# 96  Unknown   3723  45.491202     46     96       6    9    ⬤
# 97  Unknown   3723  45.491202     46     97       7    9    ⬤
# 98  Unknown   3723  45.491202     46     98       8    9    ⬤
# 99  Unknown   3723  45.491202     46     99       9    9    ⬤
#
# [100 rows x 8 columns]

# %%
# Plot the grid
chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (Each 👤 = 1%)'
).configure_view(
    stroke=None
)

chart
# Out:
# alt.Chart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

# Plot the grid
chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (Each 👤 = 1%)'
).configure_view(
    stroke=None
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/mini_project/python.qmd in <module>
#      25 )
#      26
# ---> 27 final_chart = alt.vconcat(
#      28     chart,         # the isotype grid
#      29     label_chart    # the text labels
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in vconcat(*charts, **kwargs)
#    4628 def vconcat(*charts: ConcatType, **kwargs: Any) -> VConcatChart:
#    4629     """Concatenate charts vertically."""
# -> 4630     return VConcatChart(vconcat=charts, **kwargs)
#    4631
#    4632
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in __init__(self, data, vconcat, **kwargs)
#    4536     ) -> None:
#    4537         for spec in vconcat:
# -> 4538             _check_if_valid_subspec(spec, "VConcatChart")
#    4539         super().__init__(data=data, vconcat=list(vconcat), **kwargs)  # type: ignore[arg-type]
#    4540         self.vconcat: list[ChartType]
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in _check_if_valid_subspec(spec, classname)
#    4126                 f"Consider defining the {attr} attribute in the {classname} object instead."
#    4127             )
# -> 4128             raise TypeError(msg)
#    4129
#    4130
#
# TypeError: Objects with 'config' attribute cannot be used within VConcatChart. Consider defining the config attribute in the VConcatChart object instead.

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

# Plot the grid
chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (Each 👤 = 1%)'
).configure_view(
    stroke=None
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
)

final_chart
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/mini_project/python.qmd in <module>
#      25 )
#      26
# ---> 27 final_chart = alt.vconcat(
#      28     chart,         # the isotype grid
#      29     label_chart    # the text labels
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in vconcat(*charts, **kwargs)
#    4628 def vconcat(*charts: ConcatType, **kwargs: Any) -> VConcatChart:
#    4629     """Concatenate charts vertically."""
# -> 4630     return VConcatChart(vconcat=charts, **kwargs)
#    4631
#    4632
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in __init__(self, data, vconcat, **kwargs)
#    4536     ) -> None:
#    4537         for spec in vconcat:
# -> 4538             _check_if_valid_subspec(spec, "VConcatChart")
#    4539         super().__init__(data=data, vconcat=list(vconcat), **kwargs)  # type: ignore[arg-type]
#    4540         self.vconcat: list[ChartType]
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in _check_if_valid_subspec(spec, classname)
#    4126                 f"Consider defining the {attr} attribute in the {classname} object instead."
#    4127             )
# -> 4128             raise TypeError(msg)
#    4129
#    4130
#
# TypeError: Objects with 'config' attribute cannot be used within VConcatChart. Consider defining the config attribute in the VConcatChart object instead.

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

# Plot the grid
chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (Each 👤 = 1%)'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

# Plot the grid
chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (Each 👤 = 1%)'
).configure_view(
    stroke=None
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/mini_project/python.qmd in <module>
#      25 )
#      26
# ---> 27 final_chart = alt.vconcat(
#      28     chart,         # the isotype grid
#      29     label_chart    # the text labels
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in vconcat(*charts, **kwargs)
#    4628 def vconcat(*charts: ConcatType, **kwargs: Any) -> VConcatChart:
#    4629     """Concatenate charts vertically."""
# -> 4630     return VConcatChart(vconcat=charts, **kwargs)
#    4631
#    4632
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in __init__(self, data, vconcat, **kwargs)
#    4536     ) -> None:
#    4537         for spec in vconcat:
# -> 4538             _check_if_valid_subspec(spec, "VConcatChart")
#    4539         super().__init__(data=data, vconcat=list(vconcat), **kwargs)  # type: ignore[arg-type]
#    4540         self.vconcat: list[ChartType]
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in _check_if_valid_subspec(spec, classname)
#    4126                 f"Consider defining the {attr} attribute in the {classname} object instead."
#    4127             )
# -> 4128             raise TypeError(msg)
#    4129
#    4130
#
# TypeError: Objects with 'config' attribute cannot be used within VConcatChart. Consider defining the config attribute in the VConcatChart object instead.

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

# Plot the grid
chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (Each 👤 = 1%)'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
import numpy as np

# 1. Start with the same counts
gender_counts = df[['Gender Male', 'Gender Female', 'Gender Unknown']].sum().reset_index()
gender_counts.columns = ['Gender', 'Count']
gender_counts['Gender'] = gender_counts['Gender'].str.replace('Gender ', '')
gender_counts['Percent'] = gender_counts['Count'] / gender_counts['Count'].sum() * 100

# 2. Floor the percentages
gender_counts['Icons'] = np.floor(gender_counts['Percent']).astype(int)

# 3. Calculate how many icons we're short
icons_needed = 100 - gender_counts['Icons'].sum()

# 4. Compute fractional parts to distribute remaining icons
gender_counts['Fraction'] = gender_counts['Percent'] - gender_counts['Icons']

# 5. Add 1 icon to the rows with largest fractional parts
gender_counts.loc[gender_counts.sort_values('Fraction', ascending=False).head(icons_needed).index, 'Icons'] += 1

gender_counts['Label'] = gender_counts.apply(
    lambda row: f"{row['Gender']}: {row['Percent']:.1f}%", axis=1
)

# Drop helper column
gender_counts.drop(columns='Fraction', inplace=True)

assert gender_counts['Icons'].sum() == 100,
# Out:
#   File "<ipython-input-57-0a0a7505da55>", line 28
#     assert gender_counts['Icons'].sum() == 100,
#                                                ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# 1. Start with the same counts
gender_counts = df[['Gender Male', 'Gender Female', 'Gender Unknown']].sum().reset_index()
gender_counts.columns = ['Gender', 'Count']
gender_counts['Gender'] = gender_counts['Gender'].str.replace('Gender ', '')
gender_counts['Percent'] = gender_counts['Count'] / gender_counts['Count'].sum() * 100

# 2. Floor the percentages
gender_counts['Icons'] = np.floor(gender_counts['Percent']).astype(int)

# 3. Calculate how many icons we're short
icons_needed = 100 - gender_counts['Icons'].sum()

# 4. Compute fractional parts to distribute remaining icons
gender_counts['Fraction'] = gender_counts['Percent'] - gender_counts['Icons']

# 5. Add 1 icon to the rows with largest fractional parts
gender_counts.loc[gender_counts.sort_values('Fraction', ascending=False).head(icons_needed).index, 'Icons'] += 1

gender_counts['Label'] = gender_counts.apply(
    lambda row: f"{row['Gender']}: {row['Percent']:.1f}%", axis=1
)

# Drop helper column
gender_counts.drop(columns='Fraction', inplace=True)

assert gender_counts['Icons'].sum() == 100

# %%
# Expand to one row per icon
icons_df = gender_counts.loc[gender_counts.index.repeat(gender_counts['Icons'])].reset_index(drop=True)

# Position in a 10x10 grid
icons_df['Index'] = icons_df.index
icons_df['Column'] = icons_df['Index'] % 10
icons_df['Row'] = icons_df['Index'] // 10
icons_df['Icon'] = '⬤'  # or '⬤', '■'

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

# Plot the grid
chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=300,
    height=200,
    title='Gender Distribution of Victims (Each 👤 = 1%)'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=700,
    height=200,
    title='Gender Distribution of Victims'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=400,
    height=200,
    title='Gender Distribution of Victims'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='right',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=400,
    height=200,
    title='Gender Distribution of Victims'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
import numpy as np

# 1. Start with the same counts
gender_counts = df[['Gender Male', 'Gender Female', 'Gender Unknown']].sum().reset_index()
gender_counts.columns = ['Gender', 'Count']
gender_counts['Gender'] = gender_counts['Gender'].str.replace('Gender ', '')
gender_counts['Percent'] = gender_counts['Count'] / gender_counts['Count'].sum() * 100

# 2. Floor the percentages
gender_counts['Icons'] = np.floor(gender_counts['Percent']).astype(int)

# 3. Calculate how many icons we're short
icons_needed = 100 - gender_counts['Icons'].sum()

# 4. Compute fractional parts to distribute remaining icons
gender_counts['Fraction'] = gender_counts['Percent'] - gender_counts['Icons']

# 5. Add 1 icon to the rows with largest fractional parts
gender_counts.loc[gender_counts.sort_values('Fraction', ascending=False).head(icons_needed).index, 'Icons'] += 1

gender_counts['Label'] = gender_counts.apply(
    lambda row: f"⬤ {row['Gender']}: {row['Percent']:.1f}%", axis=1
)

# Drop helper column
gender_counts.drop(columns='Fraction', inplace=True)

assert gender_counts['Icons'].sum() == 100

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='right',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=400,
    height=200,
    title='Gender Distribution of Victims'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color('Gender:N', title='Gender')
).properties(
    width=400,
    height=200,
    title='Gender Distribution of Victims'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color(
        'Gender:N', 
        title='Gender',
        scale= alt.Scale(
            domain=['Male', 'Female', 'Unknown'],
            range=['blue', 'red', 'green']
        ))
).properties(
    width=400,
    height=200,
    title='Gender Distribution of Victims'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color(
        'Gender:N', 
        title='Gender',
        scale= alt.Scale(
            domain=['Male', 'Female', 'Unknown'],
            range=['lightblue', 'lightred', 'lightgreen']
        ))
).properties(
    width=400,
    height=200,
    title='Gender Distribution of Victims'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color(
        'Gender:N', 
        title='Gender',
        scale= alt.Scale(
            domain=['Male', 'Female', 'Unknown'],
            range=['navyblue', 'red', 'green']
        ))
).properties(
    width=400,
    height=200,
    title='Gender Distribution of Victims'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color(
        'Gender:N', 
        title='Gender',
        scale= alt.Scale(
            domain=['Male', 'Female', 'Unknown'],
            range=['steelblue', 'red', 'green']
        ))
).properties(
    width=400,
    height=200,
    title='Gender Distribution of Victims'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color(
        'Gender:N', 
        title='Gender',
        scale= alt.Scale(
            domain=['Male', 'Female', 'Unknown'],
            range=['steelblue', 'crimson', 'green']
        ))
).properties(
    width=400,
    height=200,
    title='Gender Distribution of Victims'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
label_chart = alt.Chart(gender_counts).mark_text(
    align='left',
    fontSize=13
).encode(
    y=alt.Y('Gender:N', axis=None),
    text='Label:N',
    color=alt.Color('Gender:N', legend=None)
).properties(
    width=300,
    height=60
)

chart = alt.Chart(icons_df).mark_text(fontSize=20).encode(
    x=alt.X('Column:O', axis=None),
    y=alt.Y('Row:O', axis=None),
    text='Icon:N',
    color=alt.Color(
        'Gender:N', 
        title='Gender',
        scale= alt.Scale(
            domain=['Male', 'Female', 'Unknown'],
            range=['steelblue', 'crimson', 'gray']
        ))
).properties(
    width=400,
    height=200,
    title='Gender Distribution of Victims'
)

final_chart = alt.vconcat(
    chart,         # the isotype grid
    label_chart    # the text labels
).configure_view(
    stroke=None
)

final_chart
# Out:
# alt.VConcatChart(...)

# %%
df = pd.read_csv('./security_incidents.csv')

country_counts = df.groupby('Country').agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

chart = alt.Chart(df).mark_bar().encode(
    y = 'Country'
    x = country_counts
)

# Load world map data
world_map = alt.topo_feature('https://cdn.jsdelivr.net/npm/world-atlas@2/countries-110m.json', 'countries')

# base map
base = alt.Chart(world_map).mark_geoshape(
    fill='lightgray',
    stroke='white'
).properties(
    width=700,
    height=500
).project('equalEarth')

# bubbles sized by incident count
bubbles = alt.Chart(country_counts).mark_circle(opacity=0.6, color='firebrick').encode(
    longitude='Longitude:Q',
    latitude='Latitude:Q',
    size=alt.Size('Incident Count:Q', scale=alt.Scale(range=[10, 1000]), legend=alt.Legend(title="Incident Count")),
    tooltip=['Country:N', 'Incident Count:Q']
)

chart = base + bubbles
chart
# Out:
#   File "<ipython-input-73-f8e9fc2b3011>", line 10
#     y = 'Country'
#         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df = pd.read_csv('./security_incidents.csv')

country_counts = df.groupby('Country').agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

chart = alt.Chart(df).mark_bar().encode(
    y = 'Country',
    x = country_counts
)

# Load world map data
world_map = alt.topo_feature('https://cdn.jsdelivr.net/npm/world-atlas@2/countries-110m.json', 'countries')

# base map
base = alt.Chart(world_map).mark_geoshape(
    fill='lightgray',
    stroke='white'
).properties(
    width=700,
    height=500
).project('equalEarth')

# bubbles sized by incident count
bubbles = alt.Chart(country_counts).mark_circle(opacity=0.6, color='firebrick').encode(
    longitude='Longitude:Q',
    latitude='Latitude:Q',
    size=alt.Size('Incident Count:Q', scale=alt.Scale(range=[10, 1000]), legend=alt.Legend(title="Incident Count")),
    tooltip=['Country:N', 'Incident Count:Q']
)

chart = base + bubbles
chart
# Out:
# alt.LayerChart(...)

# %%
df = pd.read_csv('./security_incidents.csv')

country_counts = df.groupby('Country').agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

chart = alt.Chart(df).mark_bar().encode(
    y = 'Country',
    x = country_counts
)

chart

# Load world map data
world_map = alt.topo_feature('https://cdn.jsdelivr.net/npm/world-atlas@2/countries-110m.json', 'countries')

# base map
base = alt.Chart(world_map).mark_geoshape(
    fill='lightgray',
    stroke='white'
).properties(
    width=700,
    height=500
).project('equalEarth')

# bubbles sized by incident count
bubbles = alt.Chart(country_counts).mark_circle(opacity=0.6, color='firebrick').encode(
    longitude='Longitude:Q',
    latitude='Latitude:Q',
    size=alt.Size('Incident Count:Q', scale=alt.Scale(range=[10, 1000]), legend=alt.Legend(title="Incident Count")),
    tooltip=['Country:N', 'Incident Count:Q']
)

chart = base + bubbles
chart
# Out:
# alt.LayerChart(...)

# %%
df = pd.read_csv('./security_incidents.csv')

country_counts = df.groupby('Country').agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

chart = alt.Chart(df).mark_bar().encode(
    y = 'Country',
    x = country_counts
)

chart
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in to_dict(self, validate, format, ignore, context)
#    4031             copy.data = core.InlineData(values=[{}])
#    4032             return super(Chart, copy).to_dict(**kwds)
# -> 4033         return super().to_dict(**kwds)
#    4034
#    4035     def transformed_data(
#
# ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py in to_dict(self, validate, format, ignore, context)
#    2002         context["top_level"] = False
#    2003
# -> 2004         vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005             validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006         )
#
# ~/.local/lib/python3.10/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#    1167                 self.validate(result)
#    1168             except jsonschema.ValidationError as err:
# -> 1169                 raise SchemaValidationError(self, err) from None
#    1170         return result
#    1171
#
# SchemaValidationError: '['Country', 'Incident Count', 'Latitude', 'Longitude']' is an invalid value for `field`. Valid values are of type 'string' or 'object'.
# alt.Chart(...)

# %%
df = pd.read_csv('./security_incidents.csv')

top_ten_country = df['Country'].value_counts().nlargest(10).reset_index()
top_ten_country_column = ['Country', 'Incident Count']

chart = alt.Chart(top_ten_country).mark_bar().encode(
    y = alt.Y('Country:N', sort='-x'),
    x = alt.X('Incident Count:Q'),
    tooltip=['Country:N', 'Incident Count:Q']
).properties(
    width=500,
    height=300,
    title="Top 10 Countries by Number of Incidents"
)
chart
# Out:
# alt.Chart(...)

# %%
df = pd.read_csv('./security_incidents.csv')

top_ten_country = df['Country'].value_counts().nlargest(10).reset_index()
top_ten_country_column = ['Country', 'Incident Count']

country_counts = df.groupby('Country').agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

chart = alt.Chart(top_ten_country).mark_bar().encode(
    y = alt.Y('Country:N', sort='-x'),
    x = alt.X('Incident Count:Q'),
    tooltip=['Country:N', 'Incident Count:Q']
).properties(
    width=500,
    height=300,
    title="Top 10 Countries by Number of Incidents"
)
chart

head(country_counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/mini_project/python.qmd in <module>
#      21 chart
#      22
# ---> 23 head(country_counts)
#      24
#
# NameError: name 'head' is not defined

# %%
df = pd.read_csv('./security_incidents.csv')

top_ten_country = df['Country'].value_counts().nlargest(10).reset_index()
top_ten_country_column = ['Country', 'Incident Count']

country_counts = df.groupby('Country').agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

chart = alt.Chart(top_ten_country).mark_bar().encode(
    y = alt.Y('Country:N', sort='-x'),
    x = alt.X('Incident Count:Q'),
    tooltip=['Country:N', 'Incident Count:Q']
).properties(
    width=500,
    height=300,
    title="Top 10 Countries by Number of Incidents"
)
chart

country_counts.head()
# Out:
#        Country  Incident Count   Latitude  Longitude
# 0  Afghanistan             610  34.341969  67.308005
# 1      Algeria               2  36.829341   3.388366
# 2       Angola              21 -11.612861  16.717463
# 3    Argentina               1 -34.603803 -58.381552
# 4      Armenia               1  40.182387  44.511848

# %%
df = pd.read_csv('./security_incidents.csv')

top_ten_country = df['Country'].value_counts().nlargest(10).reset_index()
top_ten_country_column = ['Country', 'Incident Count']

country_counts = df.groupby('Country').agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

chart = alt.Chart(top_ten_country).mark_bar().encode(
    y = alt.Y('Country:N', sort='-x'),
    x = alt.X('Incident Count:Q'),
    tooltip=['Country:N', 'Incident Count:Q']
).properties(
    width=500,
    height=300,
    title="Top 10 Countries by Number of Incidents"
)
chart

country_counts.head()
top_ten_country.head()
# Out:
#                 Country  count
# 0           Afghanistan    610
# 1           South Sudan    583
# 2                 Sudan    381
# 3  Syrian Arab Republic    368
# 4               Somalia    315

# %%
df = pd.read_csv('./security_incidents.csv')

top_ten_country = df['Country'].value_counts().nlargest(10).reset_index()
top_ten_country_column = ['Country', 'Incident Count']

country_counts = df.groupby('Country').agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

chart = alt.Chart(top_ten_country).mark_bar().encode(
    y = alt.Y('Country:N', sort='-x'),
    x = alt.X('Incident Count:Q'),
    tooltip=['Country:N', 'Incident Count:Q']
).properties(
    width=500,
    height=300,
    title="Top 10 Countries by Number of Incidents"
)
chart

top_ten_country.head()
# Out:
#                 Country  count
# 0           Afghanistan    610
# 1           South Sudan    583
# 2                 Sudan    381
# 3  Syrian Arab Republic    368
# 4               Somalia    315

# %%
df = pd.read_csv('./security_incidents.csv')

top_ten_country = df['Country'].value_counts().nlargest(10).reset_index()
top_ten_country.columns = ['Country', 'Incident Count']

country_counts = df.groupby('Country').agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

chart = alt.Chart(top_ten_country).mark_bar().encode(
    y = alt.Y('Country:N', sort='-x'),
    x = alt.X('Incident Count:Q'),
    tooltip=['Country:N', 'Incident Count:Q']
).properties(
    width=500,
    height=300,
    title="Top 10 Countries by Number of Incidents"
)
chart
# Out:
# alt.Chart(...)

# %%
# 1. Load world map shape
world_map = alt.topo_feature(data.world_110m.url, 'countries')

# 2. Make sure Year is numeric
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# 3. Aggregate
yearly_counts = df.groupby(['Year', 'Country']).agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

# 4. Slider for Year
year_slider = alt.binding_range(min=yearly_counts['Year'].min(), max=yearly_counts['Year'].max(), step=1)
year_select = alt.param(name='Year', bind=year_slider, value=int(yearly_counts['Year'].min()))

# 5. Base world map
base = alt.Chart(world_map).mark_geoshape(
    fill='lightgray', stroke='white'
).project('equalEarth').properties(width=900, height=500)

# 6. Bubbles
year_bubbles = alt.Chart(yearly_counts).mark_circle(opacity=0.7, color='crimson').encode(
    longitude='Longitude:Q',
    latitude='Latitude:Q',
    size=alt.Size('Incident Count:Q', scale=alt.Scale(range=[10, 1000]), legend=alt.Legend(title="Incident Count")),
    tooltip=['Country:N', 'Incident Count:Q', 'Year:O']
).transform_filter(
    alt.datum.Year == year_select
)

# 7. Combine
chart = (base + year_bubbles).add_params(year_select)
chart
# Out:
# alt.LayerChart(...)

# %%
# 1. Load world map shape
world_map = alt.topo_feature(data.world_110m.url, 'countries')

# 2. Make sure Year is numeric
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# 3. Aggregate
yearly_counts = df.groupby(['Year', 'Country']).agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

# 4. Slider for Year
year_slider = alt.binding_range(min=yearly_counts['Year'].min(), max=yearly_counts['Year'].max(), step=1)
year_select = alt.param(name='Year', bind=year_slider, value=int(yearly_counts['Year'].min()))

# 5. Base world map
base = alt.Chart(world_map).mark_geoshape(
    fill='lightgray', stroke='white'
).project('equalEarth').properties(width=700, height=500)

# 6. Bubbles
year_bubbles = alt.Chart(yearly_counts).mark_circle(opacity=0.7, color='crimson').encode(
    longitude='Longitude:Q',
    latitude='Latitude:Q',
    size=alt.Size('Incident Count:Q', scale=alt.Scale(range=[10, 1000]), legend=alt.Legend(title="Incident Count")),
    tooltip=['Country:N', 'Incident Count:Q', 'Year:O']
).transform_filter(
    alt.datum.Year == year_select
)

# 7. Combine
chart = (base + year_bubbles).add_params(year_select)
chart
# Out:
# alt.LayerChart(...)

# %%
world_map = alt.topo_feature(data.world_110m.url, 'countries')

yearly_counts = df.groupby(['Year', 'Country']).agg({
    'Incident ID': 'count',
    'Latitude': 'mean',
    'Longitude': 'mean'
}).reset_index().rename(columns={'Incident ID': 'Incident Count'})

# Slider for Year
year_slider = alt.binding_range(min=yearly_counts['Year'].min(), max=yearly_counts['Year'].max(), step=1)
year_select = alt.param(name='Year', bind=year_slider, value=int(yearly_counts['Year'].min()))

base = alt.Chart(world_map).mark_geoshape(
    fill='lightgray', stroke='white'
).project('equalEarth').properties(width=700, height=500)

year_bubbles = alt.Chart(yearly_counts).mark_circle(opacity=0.7, color='crimson').encode(
    longitude='Longitude:Q',
    latitude='Latitude:Q',
    size=alt.Size('Incident Count:Q', scale=alt.Scale(range=[10, 1000]), legend=alt.Legend(title="Incident Count")),
    tooltip=['Country:N', 'Incident Count:Q', 'Year:O']
).transform_filter(
    alt.datum.Year == year_select
)

chart = (base + year_bubbles).add_params(year_select)

chart
# Out:
# alt.LayerChart(...)
